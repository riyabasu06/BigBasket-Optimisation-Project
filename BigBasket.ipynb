# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %%
import pandas as pd

# %%
df = pd.read_csv('BigBasket.csv', header=None)
transactions = []
for i in range(0, 7219):
  transactions.append([str(df.values[i,j]) for j in range(0, 10)])

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %%
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'burgers', 'almonds'}), support=0.005402410306136584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.26530612244897955, lift=3.0594966421073218)]),
#  RelationRecord(items=frozenset({'paneer', 'buns'}), support=0.016068707577226764, ordered_statistics=[OrderedStatistic(items_base=frozenset({'buns'}), items_add=frozenset({'paneer'}), confidence=0.32402234636871513, lift=3.2852771326344867)]),
#  RelationRecord(items=frozenset({'chicken', 'ginger garlic paste'}), support=0.00415570023548968, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ginger garlic paste'}), items_add=frozenset({'chicken'}), confidence=0.2654867256637168, lift=4.4364552605703045)]),
#  RelationRecord(items=frozenset({'vegetable basket', 'fruit basket'}), support=0.0055409336473195734, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit basket'}), items_add=frozenset({'vegetable basket'}), confidence=0.29411764705882354, lift=3.081618714249125)]),
#  RelationRecord(items=frozenset({'ginger garlic paste', 'olive oil'}), support=0.003324560188391744, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ginger garlic paste'}), items_add=frozenset({'olive oil'}), confidence=0.21238938053097342, lift=3.2552843695394844)]),
#  RelationRecord(items=frozenset({'kissan puree', 'paneer'}), support=0.005402410306136584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'kissan puree'}), items_add=frozenset({'paneer'}), confidence=0.3786407766990291, lift=3.8390558525144542)]),
#  RelationRecord(items=frozenset({'pasta', 'maggi'}), support=0.0034630835295747335, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'maggi'}), confidence=0.24752475247524755, lift=3.4562498803071797)]),
#  RelationRecord(items=frozenset({'mushroom', 'pasta'}), support=0.005402410306136584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'mushroom'}), confidence=0.38613861386138615, lift=5.004550544821089)]),
#  RelationRecord(items=frozenset({'mushroom', 'pepper spray'}), support=0.0055409336473195734, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pepper spray'}), items_add=frozenset({'mushroom'}), confidence=0.3007518796992481, lift=3.897895546766377)]),
#  RelationRecord(items=frozenset({'neckrest', 'trolly bag'}), support=0.0034630835295747335, ordered_statistics=[OrderedStatistic(items_base=frozenset({'neckrest'}), items_add=frozenset({'trolly bag'}), confidence=0.2717391304347826, lift=5.73592041698449)]),
#  RelationRecord(items=frozenset({'olive oil', 'whole wheat pasta'}), support=0.007757307106247403, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'olive oil'}), confidence=0.26666666666666666, lift=4.087190375088464)])]

# %%
def inspect(results):
  lhs = [tuple(result[2][0][0])[0] for result in results]
  rhs = [tuple(result[2][0][1])[0] for result in results]
  supports = [result[1] for result in results]
  confidences = [result[2][0][2] for result in results]
  lifts = [result[2][0][3] for result in results]
  return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
resultsinDataFrame
# Out:
#          Left Hand Side   Right Hand Side   Support  Confidence      Lift
# 0               almonds           burgers  0.005402    0.265306  3.059497
# 1                  buns            paneer  0.016069    0.324022  3.285277
# 2   ginger garlic paste           chicken  0.004156    0.265487  4.436455
# 3          fruit basket  vegetable basket  0.005541    0.294118  3.081619
# 4   ginger garlic paste         olive oil  0.003325    0.212389  3.255284
# 5          kissan puree            paneer  0.005402    0.378641  3.839056
# 6                 pasta             maggi  0.003463    0.247525  3.456250
# 7                 pasta          mushroom  0.005402    0.386139  5.004551
# 8          pepper spray          mushroom  0.005541    0.300752  3.897896
# 9              neckrest        trolly bag  0.003463    0.271739  5.735920
# 10    whole wheat pasta         olive oil  0.007757    0.266667  4.087190

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#          Left Hand Side   Right Hand Side   Support  Confidence      Lift
# 9              neckrest        trolly bag  0.003463    0.271739  5.735920
# 7                 pasta          mushroom  0.005402    0.386139  5.004551
# 2   ginger garlic paste           chicken  0.004156    0.265487  4.436455
# 10    whole wheat pasta         olive oil  0.007757    0.266667  4.087190
# 8          pepper spray          mushroom  0.005541    0.300752  3.897896
# 5          kissan puree            paneer  0.005402    0.378641  3.839056
# 6                 pasta             maggi  0.003463    0.247525  3.456250
# 1                  buns            paneer  0.016069    0.324022  3.285277
# 4   ginger garlic paste         olive oil  0.003325    0.212389  3.255284
# 3          fruit basket  vegetable basket  0.005541    0.294118  3.081619
